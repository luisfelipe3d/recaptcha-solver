# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler

from sklearn.metrics import precision_score, recall_score, f1_score

from tqdm import tqdm
from torchsummary import summary

import matplotlib.pyplot as plt

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Caminho para o seu dataset
data_dir = './editedDataset'

# Transformação para converter as imagens em tensores
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Redimensiona as imagens (ajuste conforme necessário)
    transforms.ToTensor(),
])

# Carregar o dataset
dataset = datasets.ImageFolder(root=data_dir, transform=transform)

# DataLoader para iterar pelo dataset
dataloader = DataLoader(dataset, batch_size=8, shuffle=False, num_workers=1)

def calculate_mean_std(dataloader):
    mean = 0.0
    std = 0.0
    total_images = 0

    for images, _ in dataloader:
        # Redimensiona o batch: (batch_size, 3, height, width) para (3, batch_size*height*width)
        images = images.view(3, -1)
        
        # Calcula a média e soma
        mean += images.mean(1)
        
        # Calcula o desvio padrão e soma
        std += images.std(1)
        
        total_images += 1

    # Média total
    mean /= total_images
    
    # Desvio padrão total
    std /= total_images

    return mean, std

# Calcula a média e o desvio padrão
mean, std = calculate_mean_std(dataloader)
print(f'Mean: {mean}')
print(f'Std: {std}')
# Out:
# Mean: tensor([0.4521, 0.4465, 0.4503])
# Std: tensor([0.2017, 0.2024, 0.2017])

# %%
def data_loader(data_dir, batch_size, random_seed=42, train_size=0.8, valid_size=0.1, shuffle=True):
    # Define as transformações
    normalize = transforms.Normalize(
        mean=[0.4521, 0.4465, 0.4503],  # Ajuste esses valores para o seu dataset
        std=[0.2017, 0.2024, 0.2017],
    )

    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        normalize,
    ])

    # Carregar o dataset
    dataset = datasets.ImageFolder(
        root=data_dir,
        transform=transform
    )

    num_images = len(dataset)
    print(f"Total de imagens no dataset: {num_images}")

    num_train = len(dataset)
    indices = list(range(num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    # Divisão dos índices
    train_split = int(np.floor(train_size * num_train))
    valid_split = int(np.floor((train_size + valid_size) * num_train))

    train_idx, valid_idx, test_idx = indices[:train_split], indices[train_split:valid_split], indices[valid_split:]

    # Criar samplers
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)
    test_sampler = SubsetRandomSampler(test_idx)

    # Criar data loaders
    train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
    valid_loader = DataLoader(dataset, batch_size=batch_size, sampler=valid_sampler)
    test_loader = DataLoader(dataset, batch_size=batch_size, sampler=test_sampler)

    print(f"Imagens de treinamento: {len(train_idx)}")
    print(f"Imagens de validação: {len(valid_idx)}")
    print(f"Imagens de teste: {len(test_idx)}")

    return (train_loader, valid_loader, test_loader)

# %%
batch_size = 8
train_size= 0.8
valid_size = 0.1

train_loader, valid_loader, test_loader = data_loader(data_dir=data_dir, batch_size=batch_size, 
                                                      train_size=train_size, valid_size=valid_size)
# Out:
# Total de imagens no dataset: 4194
# Imagens de treinamento: 3355
# Imagens de validação: 419
# Imagens de teste: 420

# %%
class DSSCConv(nn.Module):
    def __init__(self, in_channels, mid_channels=None, kernel_size=3, padding=1):
        super(DSSCConv, self).__init__()

        if mid_channels is None:
            mid_channels = in_channels

        # Depthwise Separable Convolution for k2
        self.k2 = nn.Sequential(
                    nn.AvgPool2d(kernel_size=4, stride=4),
                    nn.Conv2d(in_channels, in_channels, kernel_size=3, padding=1, dilation=1, stride=1, bias=False, groups=in_channels),
                    nn.Conv2d(in_channels, in_channels, kernel_size=1, bias=False),
                    nn.BatchNorm2d(in_channels),
                    )
        
        # Depthwise Separable Convolution for k3
        self.k3 = nn.Sequential(
                    nn.Conv2d(in_channels, in_channels, kernel_size=3, padding=1, dilation=1, stride=1, bias=False, groups=in_channels),
                    nn.Conv2d(in_channels, in_channels, kernel_size=1, bias=False),
                    nn.BatchNorm2d(in_channels),
                    )
        
        # Depthwise Separable Convolution for k4
        self.k4 = nn.Sequential(
                    nn.Conv2d(in_channels, in_channels, kernel_size=3, padding=1, dilation=1, stride=1, bias=False, groups=in_channels),
                    nn.Conv2d(in_channels, mid_channels, kernel_size=1, bias=False),
                    nn.BatchNorm2d(mid_channels),
                    )

    def forward(self, x):
        identity = x

        out = torch.sigmoid(torch.add(identity, F.interpolate(self.k2(x), identity.size()[2:])))
        out = torch.mul(self.k3(x), out)
        out = self.k4(out)

        return out


class DSSCVGG16(nn.Module):
    def __init__(self, num_classes=1000):
        super(DSSCVGG16, self).__init__()
        self.features = self._make_layers()
        self.classifier = nn.Sequential(
            nn.Linear(512 * 7 * 7, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

    def _make_layers(self):
        layers = []
        in_channels = 3
        
        # Configuração da arquitetura VGG16
        cfg = [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M']

        for v in cfg:
            if v == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [DSSCConv(in_channels, v),
                           nn.ReLU(inplace=True)]
                in_channels = v
                
        return nn.Sequential(*layers)

# %%
num_classes = 5
num_epochs = 100
learning_rate = 0.0001 # for Adam 0.0001 or 0.0004

model = DSSCVGG16(num_classes).to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

classes = ['Bicycle', 'Bridge', 'Bus', 'Car', 'Traffic Light']
class_correct = list(0. for i in range(num_classes))
class_total = list(0. for i in range(num_classes))

# %%
total_step = len(train_loader)

if torch.cuda.is_available():
    torch.cuda.synchronize()

start_time = time.time()

best_accuracy = 0.0
for epoch in range(num_epochs):
    # Training loop
    model.train()
    for i, (images, labels) in enumerate(train_loader):  
        images = images.to(device)
        labels = labels.to(device)
        
        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print('Epoch [{}/{}], Step [{}/{}], Loss: {:.6f}'.format(epoch+1, num_epochs, i+1, total_step, loss.item()))
    if (epoch + 1) % 10 == 0:
        checkpoint_path = f'checkpoint/checkpoint_{type(model).__name__}_num_epochs-{num_epochs}_epoch_{epoch+1}.pt'
        torch.save(model.state_dict(), checkpoint_path)
    

    # Validation loop
    with torch.no_grad():
        correct = 0
        total = 0
        model.eval()
        for images, labels in valid_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            accuracy = 100 * correct / total
            
        print('Accuracy of the network on the validation images: {:.6f} %'.format(accuracy))
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            torch.save(model.state_dict(), f'best/best_{type(model).__name__}_epoch_{num_epochs}.pt')

    # Testing loop
    true_labels = []
    predictions = []
    with torch.no_grad():
        correct = 0
        total = 0
        model.eval()
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            accuracy = 100 * correct / total
            true_labels.extend(labels.cpu().numpy())
            predictions.extend(predicted.cpu().numpy())

        print('Accuracy of the network on the test images: {:.6f} %'.format(accuracy))

    # Calcula as métricas com tratamento de divisão por zero
    precision = precision_score(true_labels, predictions, average='weighted', zero_division=0)
    recall = recall_score(true_labels, predictions, average='weighted', zero_division=0)
    f1 = f1_score(true_labels, predictions, average='weighted', zero_division=0)
    print(f'Precision: {precision:.6f}, Recall: {recall:.6f}, F1-Score: {f1:.6f}')

# Synchronize after training completion if using CUDA
if torch.cuda.is_available():
    torch.cuda.synchronize()

end_time = time.time()
total_training_time = end_time - start_time

print(f"Total training time: {total_training_time:.6f} seconds.")
# Out:
# Epoch [1/100], Step [420/420], Loss: 1.486259
# Accuracy of the network on the validation images: 31.503580 %
# Accuracy of the network on the test images: 28.333333 %
# Precision: 0.235729, Recall: 0.283333, F1-Score: 0.183587
# Epoch [2/100], Step [420/420], Loss: 2.042782
# Accuracy of the network on the validation images: 38.424821 %
# Accuracy of the network on the test images: 40.000000 %
# Precision: 0.258592, Recall: 0.400000, F1-Score: 0.308567
# Epoch [3/100], Step [420/420], Loss: 1.766140
# Accuracy of the network on the validation images: 40.334129 %
# Accuracy of the network on the test images: 42.857143 %
# Precision: 0.420670, Recall: 0.428571, F1-Score: 0.371152
# Epoch [4/100], Step [420/420], Loss: 1.253346
# Accuracy of the network on the validation images: 47.016706 %
# Accuracy of the network on the test images: 53.095238 %
# Precision: 0.477765, Recall: 0.530952, F1-Score: 0.487207
# Epoch [5/100], Step [420/420], Loss: 1.467354
# Accuracy of the network on the validation images: 55.131265 %
# Accuracy of the network on the test images: 57.619048 %
# Precision: 0.571914, Recall: 0.576190, F1-Score: 0.569705
# Epoch [6/100], Step [420/420], Loss: 0.074158
# Accuracy of the network on the validation images: 52.744630 %
# Accuracy of the network on the test images: 55.476190 %
# Precision: 0.590645, Recall: 0.554762, F1-Score: 0.552607
# Epoch [7/100], Step [420/420], Loss: 1.544838
# Accuracy of the network on the validation images: 64.677804 %
# Accuracy of the network on the test images: 68.333333 %
# Precision: 0.691550, Recall: 0.683333, F1-Score: 0.657862
# Epoch [8/100], Step [420/420], Loss: 0.392034
# Accuracy of the network on the validation images: 62.529833 %
# Accuracy of the network on the test images: 68.095238 %
# Precision: 0.719837, Recall: 0.680952, F1-Score: 0.670038
# Epoch [9/100], Step [420/420], Loss: 1.213492
# Accuracy of the network on the validation images: 61.097852 %
# Accuracy of the network on the test images: 65.952381 %
# Precision: 0.739689, Recall: 0.659524, F1-Score: 0.676970
# Epoch [10/100], Step [420/420], Loss: 0.221002
# Accuracy of the network on the validation images: 65.632458 %
# Accuracy of the network on the test images: 70.952381 %
# Precision: 0.725808, Recall: 0.709524, F1-Score: 0.708567
# Epoch [11/100], Step [420/420], Loss: 0.164740
# Accuracy of the network on the validation images: 73.985680 %
# Accuracy of the network on the test images: 70.952381 %
# Precision: 0.719040, Recall: 0.709524, F1-Score: 0.711000
# Epoch [12/100], Step [420/420], Loss: 0.932987
# Accuracy of the network on the validation images: 75.894988 %
# Accuracy of the network on the test images: 74.047619 %
# Precision: 0.746872, Recall: 0.740476, F1-Score: 0.742262
# Epoch [13/100], Step [420/420], Loss: 1.572147
# Accuracy of the network on the validation images: 76.133652 %
# Accuracy of the network on the test images: 75.000000 %
# Precision: 0.751455, Recall: 0.750000, F1-Score: 0.741158
# Epoch [14/100], Step [420/420], Loss: 1.961877
# Accuracy of the network on the validation images: 77.326969 %
# Accuracy of the network on the test images: 76.428571 %
# Precision: 0.775470, Recall: 0.764286, F1-Score: 0.766716
# Epoch [15/100], Step [420/420], Loss: 0.253214
# Accuracy of the network on the validation images: 78.281623 %
# Accuracy of the network on the test images: 75.476190 %
# Precision: 0.761907, Recall: 0.754762, F1-Score: 0.754507
# Epoch [16/100], Step [420/420], Loss: 0.026489
# Accuracy of the network on the validation images: 78.042959 %
# Accuracy of the network on the test images: 71.666667 %
# Precision: 0.753325, Recall: 0.716667, F1-Score: 0.725863
# Epoch [17/100], Step [420/420], Loss: 0.016010
# Accuracy of the network on the validation images: 78.520286 %
# Accuracy of the network on the test images: 72.857143 %
# Precision: 0.746330, Recall: 0.728571, F1-Score: 0.728115
# Epoch [18/100], Step [420/420], Loss: 0.771785
# Accuracy of the network on the validation images: 74.940334 %
# Accuracy of the network on the test images: 70.952381 %
# Precision: 0.734597, Recall: 0.709524, F1-Score: 0.714274
# Epoch [19/100], Step [420/420], Loss: 0.936444
# Accuracy of the network on the validation images: 79.236277 %
# Accuracy of the network on the test images: 77.380952 %
# Precision: 0.775537, Recall: 0.773810, F1-Score: 0.771436
# Epoch [20/100], Step [420/420], Loss: 0.405742
# Accuracy of the network on the validation images: 77.326969 %
# Accuracy of the network on the test images: 74.047619 %
# Precision: 0.759980, Recall: 0.740476, F1-Score: 0.739601
# Epoch [21/100], Step [420/420], Loss: 0.097936
# Accuracy of the network on the validation images: 78.520286 %
# Accuracy of the network on the test images: 76.904762 %
# Precision: 0.773209, Recall: 0.769048, F1-Score: 0.770329
# Epoch [22/100], Step [420/420], Loss: 0.995194
# Accuracy of the network on the validation images: 78.281623 %
# Accuracy of the network on the test images: 78.571429 %
# Precision: 0.791636, Recall: 0.785714, F1-Score: 0.786809
# Epoch [23/100], Step [420/420], Loss: 0.031230
# Accuracy of the network on the validation images: 80.906921 %
# Accuracy of the network on the test images: 78.333333 %
# Precision: 0.785676, Recall: 0.783333, F1-Score: 0.779071
# Epoch [24/100], Step [420/420], Loss: 0.006401
# Accuracy of the network on the validation images: 76.372315 %
# Accuracy of the network on the test images: 71.904762 %
# Precision: 0.749116, Recall: 0.719048, F1-Score: 0.721202
# Epoch [25/100], Step [420/420], Loss: 0.001585
# Accuracy of the network on the validation images: 81.145585 %
# Accuracy of the network on the test images: 77.142857 %
# Precision: 0.775615, Recall: 0.771429, F1-Score: 0.771561
# Epoch [26/100], Step [420/420], Loss: 0.219007
# Accuracy of the network on the validation images: 77.565632 %
# Accuracy of the network on the test images: 76.428571 %
# Precision: 0.767894, Recall: 0.764286, F1-Score: 0.762791
# Epoch [27/100], Step [420/420], Loss: 0.000024
# Accuracy of the network on the validation images: 55.131265 %
# Accuracy of the network on the test images: 53.333333 %
# Precision: 0.740303, Recall: 0.533333, F1-Score: 0.565194
# Epoch [28/100], Step [420/420], Loss: 0.000052
# Accuracy of the network on the validation images: 79.236277 %
# Accuracy of the network on the test images: 77.380952 %
# Precision: 0.782499, Recall: 0.773810, F1-Score: 0.775031
# Epoch [29/100], Step [420/420], Loss: 0.065218
# Accuracy of the network on the validation images: 80.429594 %
# Accuracy of the network on the test images: 74.761905 %
# Precision: 0.766567, Recall: 0.747619, F1-Score: 0.752469
# Epoch [30/100], Step [420/420], Loss: 0.026240
# Accuracy of the network on the validation images: 78.520286 %
# Accuracy of the network on the test images: 72.857143 %
# Precision: 0.742186, Recall: 0.728571, F1-Score: 0.731240
# Epoch [31/100], Step [420/420], Loss: 0.010587
# Accuracy of the network on the validation images: 74.940334 %
# Accuracy of the network on the test images: 73.333333 %
# Precision: 0.752226, Recall: 0.733333, F1-Score: 0.734715
# Epoch [32/100], Step [420/420], Loss: 0.000431
# Accuracy of the network on the validation images: 72.315036 %
# Accuracy of the network on the test images: 69.047619 %
# Precision: 0.758733, Recall: 0.690476, F1-Score: 0.690160
# Epoch [33/100], Step [420/420], Loss: 0.623628
# Accuracy of the network on the validation images: 79.236277 %
# Accuracy of the network on the test images: 74.285714 %
# Precision: 0.766126, Recall: 0.742857, F1-Score: 0.743498
# Epoch [34/100], Step [420/420], Loss: 0.001432
# Accuracy of the network on the validation images: 79.236277 %
# Accuracy of the network on the test images: 75.952381 %
# Precision: 0.773040, Recall: 0.759524, F1-Score: 0.760559
# Epoch [35/100], Step [420/420], Loss: 0.131883
# Accuracy of the network on the validation images: 80.190931 %
# Accuracy of the network on the test images: 75.476190 %
# Precision: 0.761046, Recall: 0.754762, F1-Score: 0.754577
# Epoch [36/100], Step [420/420], Loss: 0.015026
# Accuracy of the network on the validation images: 76.610979 %
# Accuracy of the network on the test images: 76.190476 %
# Precision: 0.772981, Recall: 0.761905, F1-Score: 0.763558
# Epoch [37/100], Step [420/420], Loss: 0.001781
# Accuracy of the network on the validation images: 81.861575 %
# Accuracy of the network on the test images: 77.619048 %
# Precision: 0.777914, Recall: 0.776190, F1-Score: 0.775695
# Epoch [38/100], Step [420/420], Loss: 0.000636
# Accuracy of the network on the validation images: 81.145585 %
# Accuracy of the network on the test images: 74.523810 %
# Precision: 0.749192, Recall: 0.745238, F1-Score: 0.745634
# Epoch [39/100], Step [420/420], Loss: 0.000051
# Accuracy of the network on the validation images: 78.997613 %
# Accuracy of the network on the test images: 78.571429 %
# Precision: 0.787111, Recall: 0.785714, F1-Score: 0.782976
# Epoch [40/100], Step [420/420], Loss: 0.002029
# Accuracy of the network on the validation images: 79.236277 %
# Accuracy of the network on the test images: 80.476190 %
# Precision: 0.808032, Recall: 0.804762, F1-Score: 0.801317
# Epoch [41/100], Step [420/420], Loss: 0.736507
# Accuracy of the network on the validation images: 81.622912 %
# Accuracy of the network on the test images: 80.238095 %
# Precision: 0.801133, Recall: 0.802381, F1-Score: 0.801087
# Epoch [42/100], Step [420/420], Loss: 0.005325
# Accuracy of the network on the validation images: 80.668258 %
# Accuracy of the network on the test images: 79.523810 %
# Precision: 0.803637, Recall: 0.795238, F1-Score: 0.796726
# Epoch [43/100], Step [420/420], Loss: 0.551909
# Accuracy of the network on the validation images: 77.326969 %
# Accuracy of the network on the test images: 74.761905 %
# Precision: 0.747443, Recall: 0.747619, F1-Score: 0.741681
# Epoch [44/100], Step [420/420], Loss: 0.000029
# Accuracy of the network on the validation images: 74.940334 %
# Accuracy of the network on the test images: 73.809524 %
# Precision: 0.752150, Recall: 0.738095, F1-Score: 0.739805
# Epoch [45/100], Step [420/420], Loss: 0.039022
# Accuracy of the network on the validation images: 79.952267 %
# Accuracy of the network on the test images: 78.809524 %
# Precision: 0.796171, Recall: 0.788095, F1-Score: 0.786831
# Epoch [46/100], Step [420/420], Loss: 0.000988
# Accuracy of the network on the validation images: 79.952267 %
# Accuracy of the network on the test images: 76.428571 %
# Precision: 0.767807, Recall: 0.764286, F1-Score: 0.764892
# Epoch [47/100], Step [420/420], Loss: 0.000013
# Accuracy of the network on the validation images: 74.940334 %
# Accuracy of the network on the test images: 78.095238 %
# Precision: 0.789016, Recall: 0.780952, F1-Score: 0.780508
# Epoch [48/100], Step [420/420], Loss: 0.000009
# Accuracy of the network on the validation images: 77.804296 %
# Accuracy of the network on the test images: 76.904762 %
# Precision: 0.789555, Recall: 0.769048, F1-Score: 0.773247
# Epoch [49/100], Step [420/420], Loss: 0.000005
# Accuracy of the network on the validation images: 80.190931 %
# Accuracy of the network on the test images: 80.000000 %
# Precision: 0.806792, Recall: 0.800000, F1-Score: 0.801501
# Epoch [50/100], Step [420/420], Loss: 0.001075
# Accuracy of the network on the validation images: 74.701671 %
# Accuracy of the network on the test images: 72.142857 %
# Precision: 0.785263, Recall: 0.721429, F1-Score: 0.726824
# Epoch [51/100], Step [420/420], Loss: 0.000007
# Accuracy of the network on the validation images: 76.610979 %
# Accuracy of the network on the test images: 75.714286 %
# Precision: 0.783395, Recall: 0.757143, F1-Score: 0.761327
# Epoch [52/100], Step [420/420], Loss: 0.000014
# Accuracy of the network on the validation images: 76.372315 %
# Accuracy of the network on the test images: 77.142857 %
# Precision: 0.781513, Recall: 0.771429, F1-Score: 0.769498
# Epoch [53/100], Step [420/420], Loss: 0.000004
# Accuracy of the network on the validation images: 75.894988 %
# Accuracy of the network on the test images: 76.904762 %
# Precision: 0.778293, Recall: 0.769048, F1-Score: 0.770287
# Epoch [54/100], Step [420/420], Loss: 0.000008
# Accuracy of the network on the validation images: 80.668258 %
# Accuracy of the network on the test images: 77.142857 %
# Precision: 0.771721, Recall: 0.771429, F1-Score: 0.769949
# Epoch [55/100], Step [420/420], Loss: 0.483127
# Accuracy of the network on the validation images: 77.326969 %
# Accuracy of the network on the test images: 73.095238 %
# Precision: 0.763641, Recall: 0.730952, F1-Score: 0.738580
# Epoch [56/100], Step [420/420], Loss: 0.000729
# Accuracy of the network on the validation images: 82.577566 %
# Accuracy of the network on the test images: 79.523810 %
# Precision: 0.795893, Recall: 0.795238, F1-Score: 0.795503
# Epoch [57/100], Step [420/420], Loss: 0.000086
# Accuracy of the network on the validation images: 76.849642 %
# Accuracy of the network on the test images: 74.523810 %
# Precision: 0.755923, Recall: 0.745238, F1-Score: 0.743716
# Epoch [58/100], Step [420/420], Loss: 0.000130
# Accuracy of the network on the validation images: 78.758950 %
# Accuracy of the network on the test images: 80.000000 %
# Precision: 0.801571, Recall: 0.800000, F1-Score: 0.795628
# Epoch [59/100], Step [420/420], Loss: 0.000003
# Accuracy of the network on the validation images: 77.565632 %
# Accuracy of the network on the test images: 78.571429 %
# Precision: 0.790927, Recall: 0.785714, F1-Score: 0.784249
# Epoch [60/100], Step [420/420], Loss: 0.157623
# Accuracy of the network on the validation images: 80.190931 %
# Accuracy of the network on the test images: 78.809524 %
# Precision: 0.803989, Recall: 0.788095, F1-Score: 0.791929
# Epoch [61/100], Step [420/420], Loss: 0.000001
# Accuracy of the network on the validation images: 81.145585 %
# Accuracy of the network on the test images: 75.714286 %
# Precision: 0.764125, Recall: 0.757143, F1-Score: 0.758870
# Epoch [62/100], Step [420/420], Loss: 0.000000
# Accuracy of the network on the validation images: 80.668258 %
# Accuracy of the network on the test images: 76.428571 %
# Precision: 0.774444, Recall: 0.764286, F1-Score: 0.766489
# Epoch [63/100], Step [420/420], Loss: 0.000004
# Accuracy of the network on the validation images: 77.088305 %
# Accuracy of the network on the test images: 77.857143 %
# Precision: 0.805490, Recall: 0.778571, F1-Score: 0.781593
# Epoch [64/100], Step [420/420], Loss: 0.000007
# Accuracy of the network on the validation images: 81.861575 %
# Accuracy of the network on the test images: 77.380952 %
# Precision: 0.777393, Recall: 0.773810, F1-Score: 0.772862
# Epoch [65/100], Step [420/420], Loss: 0.079172
# Accuracy of the network on the validation images: 83.293556 %
# Accuracy of the network on the test images: 79.761905 %
# Precision: 0.802778, Recall: 0.797619, F1-Score: 0.798653
# Epoch [66/100], Step [420/420], Loss: 0.000044
# Accuracy of the network on the validation images: 79.713604 %
# Accuracy of the network on the test images: 79.523810 %
# Precision: 0.794686, Recall: 0.795238, F1-Score: 0.792905
# Epoch [67/100], Step [420/420], Loss: 0.002824
# Accuracy of the network on the validation images: 76.372315 %
# Accuracy of the network on the test images: 76.904762 %
# Precision: 0.787163, Recall: 0.769048, F1-Score: 0.768910
# Epoch [68/100], Step [420/420], Loss: 0.000000
# Accuracy of the network on the validation images: 80.429594 %
# Accuracy of the network on the test images: 81.190476 %
# Precision: 0.815826, Recall: 0.811905, F1-Score: 0.812463
# Epoch [69/100], Step [420/420], Loss: 0.000000
# Accuracy of the network on the validation images: 80.668258 %
# Accuracy of the network on the test images: 80.238095 %
# Precision: 0.804529, Recall: 0.802381, F1-Score: 0.801514
# Epoch [70/100], Step [420/420], Loss: 0.001962
# Accuracy of the network on the validation images: 78.997613 %
# Accuracy of the network on the test images: 77.619048 %
# Precision: 0.779017, Recall: 0.776190, F1-Score: 0.774061
# Epoch [71/100], Step [420/420], Loss: 0.000003
# Accuracy of the network on the validation images: 80.906921 %
# Accuracy of the network on the test images: 78.333333 %
# Precision: 0.786716, Recall: 0.783333, F1-Score: 0.782999
# Epoch [72/100], Step [420/420], Loss: 0.000016
# Accuracy of the network on the validation images: 78.758950 %
# Accuracy of the network on the test images: 78.333333 %
# Precision: 0.796472, Recall: 0.783333, F1-Score: 0.785507
# Epoch [73/100], Step [420/420], Loss: 0.000000
# Accuracy of the network on the validation images: 79.713604 %
# Accuracy of the network on the test images: 80.238095 %
# Precision: 0.806666, Recall: 0.802381, F1-Score: 0.802324
# Epoch [74/100], Step [420/420], Loss: 2.171884
# Accuracy of the network on the validation images: 76.849642 %
# Accuracy of the network on the test images: 76.428571 %
# Precision: 0.768935, Recall: 0.764286, F1-Score: 0.764695
# Epoch [75/100], Step [420/420], Loss: 0.100982
# Accuracy of the network on the validation images: 80.190931 %
# Accuracy of the network on the test images: 80.952381 %
# Precision: 0.808292, Recall: 0.809524, F1-Score: 0.805893
# Epoch [76/100], Step [420/420], Loss: 0.000085
# Accuracy of the network on the validation images: 75.417661 %
# Accuracy of the network on the test images: 75.714286 %
# Precision: 0.783589, Recall: 0.757143, F1-Score: 0.761760
# Epoch [77/100], Step [420/420], Loss: 0.004505
# Accuracy of the network on the validation images: 80.190931 %
# Accuracy of the network on the test images: 78.333333 %
# Precision: 0.799747, Recall: 0.783333, F1-Score: 0.786750
# Epoch [78/100], Step [420/420], Loss: 0.061688
# Accuracy of the network on the validation images: 81.145585 %
# Accuracy of the network on the test images: 79.285714 %
# Precision: 0.799047, Recall: 0.792857, F1-Score: 0.793217
# Epoch [79/100], Step [420/420], Loss: 0.000583
# Accuracy of the network on the validation images: 79.713604 %
# Accuracy of the network on the test images: 79.285714 %
# Precision: 0.800251, Recall: 0.792857, F1-Score: 0.794809
# Epoch [80/100], Step [420/420], Loss: 0.000006
# Accuracy of the network on the validation images: 73.985680 %
# Accuracy of the network on the test images: 73.333333 %
# Precision: 0.760094, Recall: 0.733333, F1-Score: 0.731230
# Epoch [81/100], Step [420/420], Loss: 0.000999
# Accuracy of the network on the validation images: 78.281623 %
# Accuracy of the network on the test images: 79.285714 %
# Precision: 0.793767, Recall: 0.792857, F1-Score: 0.793239
# Epoch [82/100], Step [420/420], Loss: 0.000041
# Accuracy of the network on the validation images: 79.474940 %
# Accuracy of the network on the test images: 77.619048 %
# Precision: 0.792527, Recall: 0.776190, F1-Score: 0.779796
# Epoch [83/100], Step [420/420], Loss: 0.002252
# Accuracy of the network on the validation images: 80.190931 %
# Accuracy of the network on the test images: 78.333333 %
# Precision: 0.783768, Recall: 0.783333, F1-Score: 0.782708
# Epoch [84/100], Step [420/420], Loss: 0.000000
# Accuracy of the network on the validation images: 83.054893 %
# Accuracy of the network on the test images: 79.523810 %
# Precision: 0.800543, Recall: 0.795238, F1-Score: 0.795609
# Epoch [85/100], Step [420/420], Loss: 2.226717
# Accuracy of the network on the validation images: 78.520286 %
# Accuracy of the network on the test images: 79.523810 %
# Precision: 0.802493, Recall: 0.795238, F1-Score: 0.796055
# Epoch [86/100], Step [420/420], Loss: 0.023667
# Accuracy of the network on the validation images: 78.758950 %
# Accuracy of the network on the test images: 76.904762 %
# Precision: 0.767611, Recall: 0.769048, F1-Score: 0.766821
# Epoch [87/100], Step [420/420], Loss: 0.002183
# Accuracy of the network on the validation images: 76.133652 %
# Accuracy of the network on the test images: 75.476190 %
# Precision: 0.770213, Recall: 0.754762, F1-Score: 0.754147
# Epoch [88/100], Step [420/420], Loss: 0.030936
# Accuracy of the network on the validation images: 74.940334 %
# Accuracy of the network on the test images: 77.619048 %
# Precision: 0.796386, Recall: 0.776190, F1-Score: 0.775690
# Epoch [89/100], Step [420/420], Loss: 0.017593
# Accuracy of the network on the validation images: 78.758950 %
# Accuracy of the network on the test images: 78.809524 %
# Precision: 0.796415, Recall: 0.788095, F1-Score: 0.784815
# Epoch [90/100], Step [420/420], Loss: 0.002626
# Accuracy of the network on the validation images: 79.474940 %
# Accuracy of the network on the test images: 76.666667 %
# Precision: 0.781569, Recall: 0.766667, F1-Score: 0.770470
# Epoch [91/100], Step [420/420], Loss: 0.000127
# Accuracy of the network on the validation images: 79.713604 %
# Accuracy of the network on the test images: 76.428571 %
# Precision: 0.771763, Recall: 0.764286, F1-Score: 0.766065
# Epoch [92/100], Step [420/420], Loss: 0.483259
# Accuracy of the network on the validation images: 79.952267 %
# Accuracy of the network on the test images: 74.761905 %
# Precision: 0.769166, Recall: 0.747619, F1-Score: 0.750308
# Epoch [93/100], Step [420/420], Loss: 0.000004
# Accuracy of the network on the validation images: 80.190931 %
# Accuracy of the network on the test images: 78.095238 %
# Precision: 0.782533, Recall: 0.780952, F1-Score: 0.781108
# Epoch [94/100], Step [420/420], Loss: 0.000220
# Accuracy of the network on the validation images: 81.145585 %
# Accuracy of the network on the test images: 77.619048 %
# Precision: 0.783492, Recall: 0.776190, F1-Score: 0.776351
# Epoch [95/100], Step [420/420], Loss: 0.019696
# Accuracy of the network on the validation images: 77.326969 %
# Accuracy of the network on the test images: 76.428571 %
# Precision: 0.768793, Recall: 0.764286, F1-Score: 0.761569
# Epoch [96/100], Step [420/420], Loss: 0.000007
# Accuracy of the network on the validation images: 80.906921 %
# Accuracy of the network on the test images: 75.952381 %
# Precision: 0.764034, Recall: 0.759524, F1-Score: 0.760323
# Epoch [97/100], Step [420/420], Loss: 0.049026
# Accuracy of the network on the validation images: 77.088305 %
# Accuracy of the network on the test images: 79.761905 %
# Precision: 0.797694, Recall: 0.797619, F1-Score: 0.796217
# Epoch [98/100], Step [420/420], Loss: 0.000001
# Accuracy of the network on the validation images: 77.088305 %
# Accuracy of the network on the test images: 75.952381 %
# Precision: 0.766489, Recall: 0.759524, F1-Score: 0.760141
# Epoch [99/100], Step [420/420], Loss: 0.000000
# Accuracy of the network on the validation images: 79.952267 %
# Accuracy of the network on the test images: 77.857143 %
# Precision: 0.779153, Recall: 0.778571, F1-Score: 0.776455
# Epoch [100/100], Step [420/420], Loss: 0.000158
# Accuracy of the network on the validation images: 78.997613 %
# Accuracy of the network on the test images: 77.619048 %
# Precision: 0.777090, Recall: 0.776190, F1-Score: 0.770623
# Total training time: 4157.641955 seconds.

# %%
print('VGG16 and Depthwise Separable Convolution Summary:')
summary(model, (3, 224, 224))
# Out:
# VGG16 and Depthwise Separable Convolution Summary:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#          AvgPool2d-1            [-1, 3, 56, 56]               0
#             Conv2d-2            [-1, 3, 56, 56]              27
#             Conv2d-3            [-1, 3, 56, 56]               9
#        BatchNorm2d-4            [-1, 3, 56, 56]               6
#             Conv2d-5          [-1, 3, 224, 224]              27
#             Conv2d-6          [-1, 3, 224, 224]               9
#        BatchNorm2d-7          [-1, 3, 224, 224]               6
#             Conv2d-8          [-1, 3, 224, 224]              27
#             Conv2d-9         [-1, 64, 224, 224]             192
#       BatchNorm2d-10         [-1, 64, 224, 224]             128
#          DSSCConv-11         [-1, 64, 224, 224]               0
#              ReLU-12         [-1, 64, 224, 224]               0
#         AvgPool2d-13           [-1, 64, 56, 56]               0
#            Conv2d-14           [-1, 64, 56, 56]             576
#            Conv2d-15           [-1, 64, 56, 56]           4,096
#       BatchNorm2d-16           [-1, 64, 56, 56]             128
#            Conv2d-17         [-1, 64, 224, 224]             576
#            Conv2d-18         [-1, 64, 224, 224]           4,096
#       BatchNorm2d-19         [-1, 64, 224, 224]             128
#            Conv2d-20         [-1, 64, 224, 224]             576
#            Conv2d-21         [-1, 64, 224, 224]           4,096
#       BatchNorm2d-22         [-1, 64, 224, 224]             128
#          DSSCConv-23         [-1, 64, 224, 224]               0
#              ReLU-24         [-1, 64, 224, 224]               0
#         MaxPool2d-25         [-1, 64, 112, 112]               0
#         AvgPool2d-26           [-1, 64, 28, 28]               0
#            Conv2d-27           [-1, 64, 28, 28]             576
#            Conv2d-28           [-1, 64, 28, 28]           4,096
#       BatchNorm2d-29           [-1, 64, 28, 28]             128
#            Conv2d-30         [-1, 64, 112, 112]             576
#            Conv2d-31         [-1, 64, 112, 112]           4,096
#       BatchNorm2d-32         [-1, 64, 112, 112]             128
#            Conv2d-33         [-1, 64, 112, 112]             576
#            Conv2d-34        [-1, 128, 112, 112]           8,192
#       BatchNorm2d-35        [-1, 128, 112, 112]             256
#          DSSCConv-36        [-1, 128, 112, 112]               0
#              ReLU-37        [-1, 128, 112, 112]               0
#         AvgPool2d-38          [-1, 128, 28, 28]               0
#            Conv2d-39          [-1, 128, 28, 28]           1,152
#            Conv2d-40          [-1, 128, 28, 28]          16,384
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#            Conv2d-42        [-1, 128, 112, 112]           1,152
#            Conv2d-43        [-1, 128, 112, 112]          16,384
#       BatchNorm2d-44        [-1, 128, 112, 112]             256
#            Conv2d-45        [-1, 128, 112, 112]           1,152
#            Conv2d-46        [-1, 128, 112, 112]          16,384
#       BatchNorm2d-47        [-1, 128, 112, 112]             256
#          DSSCConv-48        [-1, 128, 112, 112]               0
#              ReLU-49        [-1, 128, 112, 112]               0
#         MaxPool2d-50          [-1, 128, 56, 56]               0
#         AvgPool2d-51          [-1, 128, 14, 14]               0
#            Conv2d-52          [-1, 128, 14, 14]           1,152
#            Conv2d-53          [-1, 128, 14, 14]          16,384
#       BatchNorm2d-54          [-1, 128, 14, 14]             256
#            Conv2d-55          [-1, 128, 56, 56]           1,152
#            Conv2d-56          [-1, 128, 56, 56]          16,384
#       BatchNorm2d-57          [-1, 128, 56, 56]             256
#            Conv2d-58          [-1, 128, 56, 56]           1,152
#            Conv2d-59          [-1, 256, 56, 56]          32,768
#       BatchNorm2d-60          [-1, 256, 56, 56]             512
#          DSSCConv-61          [-1, 256, 56, 56]               0
#              ReLU-62          [-1, 256, 56, 56]               0
#         AvgPool2d-63          [-1, 256, 14, 14]               0
#            Conv2d-64          [-1, 256, 14, 14]           2,304
#            Conv2d-65          [-1, 256, 14, 14]          65,536
#       BatchNorm2d-66          [-1, 256, 14, 14]             512
#            Conv2d-67          [-1, 256, 56, 56]           2,304
#            Conv2d-68          [-1, 256, 56, 56]          65,536
#       BatchNorm2d-69          [-1, 256, 56, 56]             512
#            Conv2d-70          [-1, 256, 56, 56]           2,304
#            Conv2d-71          [-1, 256, 56, 56]          65,536
#       BatchNorm2d-72          [-1, 256, 56, 56]             512
#          DSSCConv-73          [-1, 256, 56, 56]               0
#              ReLU-74          [-1, 256, 56, 56]               0
#         AvgPool2d-75          [-1, 256, 14, 14]               0
#            Conv2d-76          [-1, 256, 14, 14]           2,304
#            Conv2d-77          [-1, 256, 14, 14]          65,536
#       BatchNorm2d-78          [-1, 256, 14, 14]             512
#            Conv2d-79          [-1, 256, 56, 56]           2,304
#            Conv2d-80          [-1, 256, 56, 56]          65,536
#       BatchNorm2d-81          [-1, 256, 56, 56]             512
#            Conv2d-82          [-1, 256, 56, 56]           2,304
#            Conv2d-83          [-1, 256, 56, 56]          65,536
#       BatchNorm2d-84          [-1, 256, 56, 56]             512
#          DSSCConv-85          [-1, 256, 56, 56]               0
#              ReLU-86          [-1, 256, 56, 56]               0
#         MaxPool2d-87          [-1, 256, 28, 28]               0
#         AvgPool2d-88            [-1, 256, 7, 7]               0
#            Conv2d-89            [-1, 256, 7, 7]           2,304
#            Conv2d-90            [-1, 256, 7, 7]          65,536
#       BatchNorm2d-91            [-1, 256, 7, 7]             512
#            Conv2d-92          [-1, 256, 28, 28]           2,304
#            Conv2d-93          [-1, 256, 28, 28]          65,536
#       BatchNorm2d-94          [-1, 256, 28, 28]             512
#            Conv2d-95          [-1, 256, 28, 28]           2,304
#            Conv2d-96          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-97          [-1, 512, 28, 28]           1,024
#          DSSCConv-98          [-1, 512, 28, 28]               0
#              ReLU-99          [-1, 512, 28, 28]               0
#        AvgPool2d-100            [-1, 512, 7, 7]               0
#           Conv2d-101            [-1, 512, 7, 7]           4,608
#           Conv2d-102            [-1, 512, 7, 7]         262,144
#      BatchNorm2d-103            [-1, 512, 7, 7]           1,024
#           Conv2d-104          [-1, 512, 28, 28]           4,608
#           Conv2d-105          [-1, 512, 28, 28]         262,144
#      BatchNorm2d-106          [-1, 512, 28, 28]           1,024
#           Conv2d-107          [-1, 512, 28, 28]           4,608
#           Conv2d-108          [-1, 512, 28, 28]         262,144
#      BatchNorm2d-109          [-1, 512, 28, 28]           1,024
#         DSSCConv-110          [-1, 512, 28, 28]               0
#             ReLU-111          [-1, 512, 28, 28]               0
#        AvgPool2d-112            [-1, 512, 7, 7]               0
#           Conv2d-113            [-1, 512, 7, 7]           4,608
#           Conv2d-114            [-1, 512, 7, 7]         262,144
#      BatchNorm2d-115            [-1, 512, 7, 7]           1,024
#           Conv2d-116          [-1, 512, 28, 28]           4,608
#           Conv2d-117          [-1, 512, 28, 28]         262,144
#      BatchNorm2d-118          [-1, 512, 28, 28]           1,024
#           Conv2d-119          [-1, 512, 28, 28]           4,608
#           Conv2d-120          [-1, 512, 28, 28]         262,144
#      BatchNorm2d-121          [-1, 512, 28, 28]           1,024
#         DSSCConv-122          [-1, 512, 28, 28]               0
#             ReLU-123          [-1, 512, 28, 28]               0
#        MaxPool2d-124          [-1, 512, 14, 14]               0
#        AvgPool2d-125            [-1, 512, 3, 3]               0
#           Conv2d-126            [-1, 512, 3, 3]           4,608
#           Conv2d-127            [-1, 512, 3, 3]         262,144
#      BatchNorm2d-128            [-1, 512, 3, 3]           1,024
#           Conv2d-129          [-1, 512, 14, 14]           4,608
#           Conv2d-130          [-1, 512, 14, 14]         262,144
#      BatchNorm2d-131          [-1, 512, 14, 14]           1,024
#           Conv2d-132          [-1, 512, 14, 14]           4,608
#           Conv2d-133          [-1, 512, 14, 14]         262,144
#      BatchNorm2d-134          [-1, 512, 14, 14]           1,024
#         DSSCConv-135          [-1, 512, 14, 14]               0
#             ReLU-136          [-1, 512, 14, 14]               0
#        AvgPool2d-137            [-1, 512, 3, 3]               0
#           Conv2d-138            [-1, 512, 3, 3]           4,608
#           Conv2d-139            [-1, 512, 3, 3]         262,144
#      BatchNorm2d-140            [-1, 512, 3, 3]           1,024
#           Conv2d-141          [-1, 512, 14, 14]           4,608
#           Conv2d-142          [-1, 512, 14, 14]         262,144
#      BatchNorm2d-143          [-1, 512, 14, 14]           1,024
#           Conv2d-144          [-1, 512, 14, 14]           4,608
#           Conv2d-145          [-1, 512, 14, 14]         262,144
#      BatchNorm2d-146          [-1, 512, 14, 14]           1,024
#         DSSCConv-147          [-1, 512, 14, 14]               0
#             ReLU-148          [-1, 512, 14, 14]               0
#        AvgPool2d-149            [-1, 512, 3, 3]               0
#           Conv2d-150            [-1, 512, 3, 3]           4,608
#           Conv2d-151            [-1, 512, 3, 3]         262,144
#      BatchNorm2d-152            [-1, 512, 3, 3]           1,024
#           Conv2d-153          [-1, 512, 14, 14]           4,608
#           Conv2d-154          [-1, 512, 14, 14]         262,144
#      BatchNorm2d-155          [-1, 512, 14, 14]           1,024
#           Conv2d-156          [-1, 512, 14, 14]           4,608
#           Conv2d-157          [-1, 512, 14, 14]         262,144
#      BatchNorm2d-158          [-1, 512, 14, 14]           1,024
#         DSSCConv-159          [-1, 512, 14, 14]               0
#             ReLU-160          [-1, 512, 14, 14]               0
#        MaxPool2d-161            [-1, 512, 7, 7]               0
#           Linear-162                 [-1, 4096]     102,764,544
#             ReLU-163                 [-1, 4096]               0
#          Dropout-164                 [-1, 4096]               0
#           Linear-165                 [-1, 4096]      16,781,312
#             ReLU-166                 [-1, 4096]               0
#          Dropout-167                 [-1, 4096]               0
#           Linear-168                    [-1, 5]          20,485
# ================================================================
# Total params: 124,421,044
# Trainable params: 124,421,044
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 719.63
# Params size (MB): 474.63
# Estimated Total Size (MB): 1194.83
# ----------------------------------------------------------------

# %%
print(model)
# Out:
# DSSCVGG16(
#   (features): Sequential(
#     (0): DSSCConv(
#       (k2): Sequential(
#         (0): AvgPool2d(kernel_size=4, stride=4, padding=0)
#         (1): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3, bias=False)
#         (2): Conv2d(3, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k3): Sequential(
#         (0): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3, bias=False)
#         (1): Conv2d(3, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k4): Sequential(
#         (0): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3, bias=False)
#         (1): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ReLU(inplace=True)
#     (2): DSSCConv(
#       (k2): Sequential(
#         (0): AvgPool2d(kernel_size=4, stride=4, padding=0)
#         (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k3): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k4): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): DSSCConv(
#       (k2): Sequential(
#         (0): AvgPool2d(kernel_size=4, stride=4, padding=0)
#         (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k3): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k4): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#         (1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): ReLU(inplace=True)
#     (7): DSSCConv(
#       (k2): Sequential(
#         (0): AvgPool2d(kernel_size=4, stride=4, padding=0)
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k3): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k4): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): DSSCConv(
#       (k2): Sequential(
#         (0): AvgPool2d(kernel_size=4, stride=4, padding=0)
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k3): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k4): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): ReLU(inplace=True)
#     (12): DSSCConv(
#       (k2): Sequential(
#         (0): AvgPool2d(kernel_size=4, stride=4, padding=0)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#         (2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k3): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#         (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k4): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#         (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): ReLU(inplace=True)
#     (14): DSSCConv(
#       (k2): Sequential(
#         (0): AvgPool2d(kernel_size=4, stride=4, padding=0)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#         (2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k3): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#         (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k4): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#         (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): DSSCConv(
#       (k2): Sequential(
#         (0): AvgPool2d(kernel_size=4, stride=4, padding=0)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#         (2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k3): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#         (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k4): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#         (1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): ReLU(inplace=True)
#     (19): DSSCConv(
#       (k2): Sequential(
#         (0): AvgPool2d(kernel_size=4, stride=4, padding=0)
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (2): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k3): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k4): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (20): ReLU(inplace=True)
#     (21): DSSCConv(
#       (k2): Sequential(
#         (0): AvgPool2d(kernel_size=4, stride=4, padding=0)
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (2): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k3): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k4): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): DSSCConv(
#       (k2): Sequential(
#         (0): AvgPool2d(kernel_size=4, stride=4, padding=0)
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (2): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k3): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k4): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (25): ReLU(inplace=True)
#     (26): DSSCConv(
#       (k2): Sequential(
#         (0): AvgPool2d(kernel_size=4, stride=4, padding=0)
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (2): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k3): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k4): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (27): ReLU(inplace=True)
#     (28): DSSCConv(
#       (k2): Sequential(
#         (0): AvgPool2d(kernel_size=4, stride=4, padding=0)
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (2): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k3): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (k4): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#         (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=5, bias=True)
#   )
# )
